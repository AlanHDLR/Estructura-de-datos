# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanHDLR/Estructura-de-datos/blob/main/Arboles_1310.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class NodoBinario:
    def __init__( self , value , left = None , right = None ):
        self.data = value
        self.left = left
        self.right = right

class NodoTernario:
    def __init__( self , value , left = None , center = None , right = None ):
        self.data = value
        self.left = left
        self.center = center
        self.right = right

# %%
arbol_1 = NodoBinario("R" , NodoBinario("C") , NodoBinario("H") )
print(arbol_1.right.data)
arbol_2 = NodoTernario( 4 , NodoTernario(3,\
          NodoTernario(5 , left = NodoTernario(2)) , \
          NodoTernario(5) , NodoTernario(2) ), None ,  NodoTernario(5) )
print(arbol_2.left.right.data)
print(arbol_2.data)
print(arbol_2.left.center.data)
print(arbol_2.right.left)
# Out:
# H
# 2
# 4
# 5
# None

# %% [markdown]
# ![Captura de pantalla 2021-11-30 120544.png](data:image/png;base64,...)

# %%
class NodoBinario:
    def __init__( self , value , left = None , right = None ):
        self.data = value
        self.left = left
        self.right = right

class ArbolNodoBinario:
    def __init__( self ):
        self.root = None
    
    def insert( self , value ):
        if self.root == None:
            self.root = NodoBinario( value )
        else:
            self.__insert_nodo( self.root , values )

    def __insert_nodo( self , nodo , value ):
        if nodo.data == value:
            pass
        elif value < nodo.data:  # ir a la izquierda
            if nodo.left == None:
                nodo.left = NodoBinario( value )
            else:
                self.__insert_nodo( nodo.left , value )
        else:  # ir a la derecha
            if nodo.right == None:
                nodo.right = NodoBinario( value )
            else:
                self.__insert_nodo( nodo.right , value )

    def transversal( self , formato = "posorden" ):
        if formato == "posorden":
            self.recorrido_pos( self.root )
        elif formato == "preorden":
            self.recorrido_pre( self.root )
        else:   # inorden
            self.recorrido_in( self.root )
        print()
    
    def recorrido_pos( self, nodo ):
        if nodo != None:
            self.recorrido_pos( nodo.left )
            self.recorrido_pos( nodo.right )
            print( str(nodo.data) , end=" , " )

    def recorrido_pre( self , nodo ):
        if nodo != None:
            print( str(nodo.data) , end=" , " )
            self.recorrido_pre( nodo.left )
            self.recorrido_pre( nodo.right )

    def recorrido_in( self , nodo ):
        if nodo != None:
            self.recorrido_in( nodo.left )
            print( str(nodo.data) , end=" , " )
            self.recorrido_in( nodo.right )

    def search( self , value ):
        if self.root == None:
            print("El árbol esta vacío")
            return None
        else:
            self.__search( self.root , value )

    def __search( self , nodo , value ):
        if nodo.data == None:
            print("El dato no existe ene el árbol")
            return None
        elif nodo.data == value:
            print("Encontrado")
            return nodo
        elif value < nodo.data:
            return self.__buscar( nodo.left , value )
        else:
            return self.__buscar( nodo.right , value )

# %%
arb1 = BuscarArbolBinario()
arb1.insert(60)
arb1.insert(30)
arb1.insert(15)
arb1.insert(40)
arb1.transversal("posorden")
arb1.transversal("preorden")
arb1.transversal("inorden")
